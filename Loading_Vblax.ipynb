# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# Set the start and end dates for the data
start_date = '2015-01-01'
end_date = '2023-01-01'

# Define the ticker symbol for VBLAX
ticker = 'VBLAX'

# Use pandas-datareader to get the historical data
data = web.DataReader('VBLAX', 'yahoo', start_date, end_date)

# Extract the daily returns and trading volume
returns = data['Adj Close'].pct_change()
volume = data['Volume']

# Combine the returns and volume into a DataFrame
df = pd.concat([returns, volume], axis=1)
df.columns = ['returns', 'volume']

# Export the data to a CSV file
df.to_csv('VBLAX_daily_returns_volume.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/c2/m9k0t3cx7ll7gxptyf12gq680000gn/T/ipykernel_3695/2653699308.py in <module>
#      11
#      12 # Use pandas-datareader to get the historical data
# ---> 13 data = web.DataReader('VBLAX', 'yahoo', start_date, end_date)
#      14
#      15 # Extract the daily returns and trading volume
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     368
#     369     if data_source == "yahoo":
# ...

# %%
start  = datetime(2015, 1, 1)
end    = datetime(2022, 1, 1)

# %%
import yfinance as yf
import pandas as pd

# Download the historical data
stock_prices = yf.download('VBLAX', start=start, end=end)

# Calculate the daily percentage change of the adjusted close prices
daily_returns = stock_prices['Adj Close'].pct_change()

# Add the trading volume column to the daily_returns DataFrame
daily_returns['Volume'] = stock_prices['Volume']

data = pd.DataFrame({'Daily Returns': daily_returns, 'Trading Volume': stock_prices['Volume']})
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                                          Daily Returns  \
# Date
# 2019-02-07 00:00:00                                                NaN
# 2019-02-08 00:00:00                                           0.002226
# 2019-02-11 00:00:00                                          -0.002221
# 2019-02-12 00:00:00                                          -0.002226
# 2019-02-13 00:00:00                                           -0.00223
# ...                                                                ...
# 2021-12-28 00:00:00                                          -0.002546
# 2021-12-29 00:00:00                                          -0.008296
# 2021-12-30 00:00:00                                           0.007079
# 2021-12-31 00:00:00                                           0.003651
# Volume               Date
# 2019-02-07    0
# 2019-02-08    0
# 2019-02-1...
#
# ...
